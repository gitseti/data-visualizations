# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# Define colors
GRAY1, GRAY2, GRAY3 = '#231F20', '#414040', '#555655'
GRAY4, GRAY5, GRAY6 = '#646369', '#76787B', '#828282'
GRAY7, GRAY8, GRAY9 = '#929497', '#A6A6A5', '#BFBEBE'
BLUE1, BLUE2, BLUE3 = '#174b7e','#2e5d8b', '#456f98', 
BLUE4, BLUE5, BLUE6 = '#5d81a5', '#7493b2', '#7493b2',
BLUE7, BLUE8, BLUE9 = '#8ba5bf', '#a2b7cb', '#b9c9d8'
RED1, RED2 = '#C3514E', '#E6BAB7'
GREEN1, GREEN2 = '#0C8040', '#9ABB59'
ORANGE1 = '#F79747'
# Configure plot font family to Arial
plt.rcParams['font.family'] = 'Arial'

# %%
data = pd.read_csv('../datasets/co2_emissions_kt_by_country.csv')

# %%
emissions_of_germany = data[data.country_name == "Germany"]
emissions_of_germany.head()
reduction_target_by_2030 = emissions_of_germany.iloc[0]["value"] * 0.65

# %%
X = emissions_of_germany.iloc[:, 2].to_numpy().reshape(-1, 1)
X_pred = np.append(X_np, np.arange(2020, 2051, 1)).reshape(-1, 1)
Y = emissions_of_germany.iloc[:, 3].to_numpy().reshape(-1, 1)

linear_regressor = LinearRegression() 
linear_regressor.fit(X, Y) 

Y_pred = linear_regressor.predict(X_pred)

# %%
ax = emissions_of_germany.plot(x = "year", y = "value", legend=None, color=BLUE8)
fig = ax.get_figure()

ax.set_title('CO2 emissions are expected to reach the 65% goal before 2030', loc="left", color=GRAY4)

ax.plot(X_pred, Y_pred,color=BLUE3, linewidth=1)

markers_on = [40]
ax.plot(np.arange(1990, 2051, 1), np.full(61, reduction_target_by_2030), linewidth=0.5, color=GRAY9, 
        markevery=markers_on, marker='|', markeredgecolor=ORANGE1, markersize=30)

ax.annotate("Germany will have reached 65% CO2 reduction\n by 2030", xy=(2032, reduction_target_by_2030 + 15000), xycoords='data', color=BLUE1, weight='bold')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_color(GRAY4)
ax.spines['left'].set_color(GRAY4)

ax.tick_params(axis='x', colors=GRAY4, which='both')
ax.tick_params(axis='y', colors=GRAY4, which='both')

ax.set_ylabel('CO2 emission in kt', loc='top', color=GRAY4)
ax.set_xlabel('Year', loc='left', color=GRAY4)

ax.set_xlim(xmax=2050)
# Out:
# (1987.0, 2050.0)
